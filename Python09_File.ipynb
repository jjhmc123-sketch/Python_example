# %%
f = open("demofile.txt")

print(f)
# Out:
# <_io.TextIOWrapper name='demofile.txt' mode='r' encoding='utf-8'>

# %%
f = open("demofile.txt", "rt")

# %%
f = open("demofile.txt")
print(f.read())
# Out:
# Hello print!

# %%
with open("demofile.txt") as f:
 print(f.read())
# Out:
# Hello print!

# %%
f = open("demofile.txt")
print(f.readline())
f.close()

# %%
with open("demofile.txt") as f:
    print(f.readline())
    print(f.readline())
# Out:
# Hello print!

# %%
with open("demofile.txt") as f:
    for x in f:
        print(x)
# Out:
# Hello print!

# %%
with open("demofile.txt", "a") as f:
    f.write("Now the file has more content!")

# open and read the file after the appending:
with open("demofile.txt") as f:
    print(f.read())
# Out:
# Hello print!Now the file has more content!

# %%
f = open("myfile.txt", "x")

# %%
import os
os.remove("demofile.txt")

# %%
with open("demofile.txt", "w") as f:
    f.write("Woops! I have deleted the content!")

# open and read the file after the overwriting:
with open("demofile.txt") as f:
    print(f.read())
# Out:
# Woops! I have deleted the content!

# %%
import os
os.rmdir("myfolder") ##Remove 하였음.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 import os
# ----> 2 os.rmdir("myfolder")
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'myfolder'
